# %% [markdown]
# # Model local files vs. country playlist

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Read data

# %%
df_local = pd.read_pickle("../../2024_12_27__attempt_2/Local/extracted data/2025_01_07_local_music_librosa_features.pkl")
df_country = pd.read_pickle("../../2024_12_27__attempt_2/Youtube/extracted data/2025_01_08_Country_Music_Playlist_2024.pkl").rename(columns={'title': 'track_name'})

# %%
# Combine
# List of common columns we want to keep (librosa features + track_name)
common_cols = ['track_name', 'mfcc_0', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 
                  'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 
                  'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 
                  'mfcc_17', 'mfcc_18', 'mfcc_19', 'spectral_centroid', 'chroma_0', 
                  'chroma_1', 'chroma_2', 'chroma_3', 'chroma_4', 'chroma_5', 
                  'chroma_6', 'chroma_7', 'chroma_8', 'chroma_9', 'chroma_10', 
                  'chroma_11', 'tempo']

# Create new dataframes with only the common columns
df_country_subset = df_country[common_cols].copy()
df_local_subset = df_local[common_cols].copy()

# Add 'local' column
df_country_subset['local'] = 0
df_local_subset['local'] = 1

# Combine the dataframes
df_combined = pd.concat([df_country_subset, df_local_subset], ignore_index=True)

# %%
df_combined.local.value_counts()
# Out:
# 1    216
# 0    150
# Name: local, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Prep

# %%
# Feat cols
music_feat_cols = [col for col in common_cols if col != 'track_name']

# Step 1: Prepare the data
X = df_combined[music_feat_cols]
y = df_combined['local']

# # Hold out 5 songs from each class
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=10, stratify=y, random_state=42)

# %%
## Instead of withholding 10 random samples, let's specify how many from each class we desire
# Get indices for each class
positive_indices = np.where(y == 1)[0]
negative_indices = np.where(y == 0)[0]

# Set vars for n% of each class
hld_perc = .1
n_pos_ind_hld = round(hld_perc * len(positive_indices))
n_neg_ind_hld = round(hld_perc * len(negative_indices))

# Split positive class
X_pos_train, X_pos_test, y_pos_train, y_pos_test = train_test_split(
    X.iloc[positive_indices],  # Positional row indexing
    y.iloc[positive_indices],
    test_size=n_pos_ind_hld,
    random_state=42
)

# Split negative class
X_neg_train, X_neg_test, y_neg_train, y_neg_test = train_test_split(
    X.iloc[negative_indices],  # Positional row indexing
    y.iloc[negative_indices],
    test_size=n_neg_ind_hld,
    random_state=42
)

# %%
## Combine results
X_train = pd.concat([X_pos_train, X_neg_train])
X_test = pd.concat([X_pos_test, X_neg_test])
y_train = pd.concat([y_pos_train, y_neg_train])
y_test = pd.concat([y_pos_test, y_neg_test])

# %%
print(len(X_train), len(y_train))
# Out:
# 329 329

# %%
print(len(X_test), len(y_test))
# Out:
# 37 37

# %%
unique, counts = np.unique(y_test, return_counts=True)
count_dict = dict(zip(unique, counts))
print(count_dict)
# Out:
# {0: 15, 1: 22}

# %%
print(n_neg_ind_hld, n_pos_ind_hld)
# Out:
# 15 22

# %% [markdown]
# ### GS

# %%
# CV GS
# Step 2: Perform cross-validated grid search
param_grid = {
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.1, 0.3],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0]
}

# %%
xgb = XGBClassifier(eval_metric='logloss', random_state=42)

# %%
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.3],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='accuracy')

# %%
results_df = pd.DataFrame(grid_search.cv_results_)

# %%
results_df.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 28       0.151204      0.005467         0.003391        0.000798
# 75       0.171451      0.004397         0.003591        0.000489
# 45       0.173343      0.007827         0.003790        0.001163
# 32       0.269590      0.013418         0.005984        0.005499
# 35       0.378405      0.026572         0.003891        0.000661
#
#    param_learning_rate param_max_depth param_n_estimators param_subsample  \
# 28                 0.1               3                100             0.9
# 75                 0.3               5                200             0.8
# 45                 0.1               5                100             0.8
# 32                 0.1               3                200             1.0
# 35                 0.1               3                300             1.0
#
#                                                params  split0_test_score  \
# 28  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.893939
# 75  {'learning_rate': 0.3, 'max_depth': 5, 'n_esti...           0.863636
# 45  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.878788
# 32  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.878788
# 35  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.878788
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 28           0.893939           0.909091           0.893939
# 75           0.893939           0.924242           0.893939
# 45           0.878788           0.909091           0.909091
# 32           0.893939           0.924242           0.893939
# 35           0.893939           0.924242           0.893939
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 28           0.953846         0.908951        0.023202                1
# 75           0.938462         0.902844        0.026162                2
# 45           0.938462         0.902844        0.022379                2
# 32           0.923077         0.902797        0.017914                4
# 35           0.923077         0.902797        0.017914                4

# %%
# Step 3: Train the model with best parameters
best_model = grid_search.best_estimator_
best_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=42, ...)

# %%
# Step 4: Predict on held-out songs
y_pred = best_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Accuracy on held-out songs: {accuracy:.2f}")
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.9}
# Accuracy on held-out songs: 0.92

# %%
# Step 5: Proba output
y_pred_proba = best_model.predict_proba(X_test)[:, 1]  # Probability of class 1

# %%
# Create a results dataframe
df_preds = pd.DataFrame({
    'track_name': df_combined.loc[X_test.index, 'track_name'],
    'actual': y_test,
    'predicted': y_pred_proba.round(),
    'probability': y_pred_proba.round(3)
})

# %%
# Add a 'correct' column
df_preds['correct'] = df_preds['actual'] == df_preds['predicted']

# %%
df_preds
# Out:
#                                             track_name  actual  predicted  \
# 351                               Our Last Moments.mp3       1        0.0
# 363                                    Whisperlude.mp3       1        1.0
# 288                                       04 12_51.m4a       1        1.0
# 327              Pogo - Star Charts - 10 The Climb.mp3       1        1.0
# 165                             01-02 - Man Of Oil.mp3       1        1.0
# 261           10 Life Is Simple In The Moonlight 1.mp3       1        1.0
# 332                                    Austin 1911.mp3       1        1.0
# 223  TheTallestManOnEarth-Shallowgrave-02-PistolDre...       1        1.0
# 355                                       PuffLove.mp3       1        1.0
# 289                       05 You Talk Way Too Much.m4a       1        1.0
# 309      Pogo - Kindred Shadow - 05 Ode For Lovers.mp3       1        0.0
# 180                                 02 Hocus Pocus.mp3       1        1.0
# 340                                 Expialidocious.mp3       1        1.0
# 159                                        05 Bees.m4a       1        1.0
# 217                               06 King of Spain.mp3       1        1.0
# 326  Pogo - Star Charts - 09 Do Something Rhythmic.mp3       1        1.0
# 322            Pogo - Star Charts - 05 Featherfunk.mp3       1        1.0
# 168                              01 In The Flowers.m4a       1        1.0
# 304                 精神 _ Pogo_284667071_soundcloud.mp3       1        1.0
# 216                     05 The Drying of the Lawns.mp3       1        1.0
# 336                                       Buzzwing.mp3       1        1.0
# 292                             08 Under Control 1.m4a       1        1.0
# 73     Luke Combs - Fast Car (Official Live Video).mp3       0        0.0
# 18   Carrie Underwood - Give Her That (Official Lyr...       0        0.0
# 118  Post Malone - I Had Some Help (feat. Morgan Wa...       0        0.0
# 78   Luke Combs – Ain’t No Love In Oklahoma (From T...       0        0.0
# 76   Luke Combs - The Kind of Love We Make (Officia...       0        0.0
# 31   Dan + Shay - Save Me The Trouble (Official Mus...       0        1.0
# 64   Kenny Chesney - Take Her Home (Official Music ...       0        0.0
# 141  Tim McGraw - Standing Room Only (Official Musi...       0        0.0
# 68   Lee Brice - One of Them Girls (Official Music ...       0        0.0
# 82   Mitchell Tenpenny - We Got History (Official M...       0        0.0
# 110  Old Dominion - Memory Lane (Official Music Vid...       0        0.0
# 12   Brett Young - You Didn't (Official Music Video...       0        0.0
# 36   Easton Corbin - Marry That Girl (Lyric Video).mp3       0        0.0
# 9    Blake Shelton - Nobody But You (Duet with Gwen...       0        0.0
# 19   Carrie Underwood - Out Of That Truck (Official...       0        0.0
#
#      probability  correct
# 351        0.432    False
# 363        0.789     True
# 288        0.974     True
# 327        0.978     True
# 165        0.995     True
# 261        0.800     True
# 332        0.681     True
# 223        0.992     True
# 355        0.991     True
# 289        0.995     True
# 309        0.401    False
# 180        0.884     True
# 340        0.837     True
# 159        0.983     True
# 217        0.964     True
# 326        0.999     True
# 322        0.674     True
# 168        0.999     True
# 304        0.638     True
# 216        0.961     True
# 336        0.953     True
# 292        0.878     True
# 73         0.041     True
# 18         0.118     True
# 118        0.137     True
# 78         0.015     True
# 76         0.022     True
# 31         0.668    False
# 64         0.026     True
# 141        0.007     True
# 68         0.047     True
# 82         0.308     True
# 110        0.019     True
# 12         0.417     True
# 36         0.270     True
# 9          0.345     True
# 19         0.054     True

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[14,  1],
#        [ 2, 20]], dtype=int64)

# %%
# Create a heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Final Remarks

# %% [markdown]
# **Note:** The model achieved an accuracy of 92% on the test set, indicating strong performance on this dataset. I'm happy and surprised these results were replicated in a reshuffle of the holdout sets.
